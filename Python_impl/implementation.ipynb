# %%
# key - assignment name -> time -> deadline

total = 43
days = [7, 7, 4, 6, 4, 7, 8]
# today = 0
def find_time_del(days:list, time_dif:int, current:int = 0, total:int=41):
    n = len(days)
    sum = (time_dif // n)*total
    remain = time_dif%n
    while remain != 0:
        sum += days[current]
        current -= 1
        remain -= 1
    return sum

# thursday at the 4th work hour - time_dif=4, deadline_hour=4
def find_deadline(days:list, time_dif:int, start_hour:int=0, deadline_hour:int = 0, current:int = 0, total:int=43):
    n = len(days)
    sum = (time_dif//n)*total
    remain = time_dif%n
    while remain != 0:
        sum += days[current]
        current += 1
        remain -= 1
    sum += deadline_hour - start_hour
    return sum

def reverse_hours(days:list, hours:int, start_day:int):
    iter = start_day
    while hours > 0:
        hours -= days[iter]
        iter += 1
        if iter > len(days)-1: iter=0
    return iter, hours+days[iter]

    

print(find_time_del(days, 2))
print(find_deadline(days, time_dif=6, start_hour=5, deadline_hour=8))
print(reverse_hours(days, 23, 0))
# Out:
# 15
# 38
# (4, 3)

# %%
class day:
    def __init__(self, name:str, hours:int, splits):
        self.name = name
        self.hours = hours
        self.splits = splits
# global variables
total = 41
#       M  T  W  TH F  SA SU
days = [day("Monday", 5, splits=[9.5,10.5,11.5,20,21]), 
        day("Tuesday", 4, splits=[9.5,10.5,20,21]),
        day("Wednesday", 6, splits=[9.5,10.5,11.5,17,20,21]),
        day("Thursday", 4, splits=[9.5,10.5,20,21]),
        day("Friday", 7, splits=[9.5,10.5,11.5,14,15.5,17,20,21]),
        day("Saturday", 8, splits=[9.66,10.82,12,14.33,15.66,17,20,21]),
        day("Sunday", 7, splits=[10.82,12,14.33,15.66,17,20,21])]

def get_hour_dif(days:list, time_dif:int, prev_day:int, current_day:int, prev_hour:int, current_hour:int):
    '''
    time_dif is the number of days difference between two days
    prev_hour is the hour of the previous date
    current_hour is the hour at the current date
    prev_hour must be <= current_hour if time_dif is 0
    '''
    if time_dif == 0 and prev_hour > current_hour: 
        print("Error - the time entered is before the previous date")
        return None
    if time_dif == 0:
        return current_hour - prev_hour
    
    n = len(days)
    sum = (time_dif//n)*total
    remain = time_dif%n
    while remain != 0:
        sum += days[current_day].hours
        current_day -= 1
        remain -= 1
    sum += (days[prev_day].hours - prev_hour)
    sum -= (days[current_day].hours - current_hour)
    return sum

get_hour_dif(days, time_dif=2, prev_day=0, current_day=2, prev_hour=4, current_hour=1)
# Out:
# 7

# %%
import random

class Assign: 
    def __init__(self, name, duration, deadline):
        self.name = name
        self.duration = duration
        self.deadline = deadline

    def __str__(self):
        return f"{self.name} -> dur: {self.duration} -> deadline: {self.deadline}"

# these times were set on 10/8/23 - make sure to iteratively subtract from each 
# deadline the number of days which have passed leading up to the most recent
# update point
Assignments = [
    Assign("Data Challenge Outline - timeline work", 2, 43), 
    Assign("Delphi Model Validation", 3, 24),
    Assign("Delphi Model Latency", 3, 24),
    Assign("Delphi Model Throughput", 3, 24),
    Assign("CSE 3500 PS3 - p1", 1, 45), 
    Assign("CSE 3500 PS3 - p2", 1, 45), 
    Assign("CSE 3500 PS3 - p3", 1, 45),
    Assign("CSE 3500 PS3 - p5", 1, 45),
    Assign("STAT 3515 Weakness Identification", 2, -15), 
    Assign("STAT 3515 EP1 - One-Way Fixed Effects", 2, 9), 
    Assign("STAT 3515 EP2 - One Way Random Effects", 2, 9),
    Assign("STAT 3515 EP3 - Randomized Complete Block Design", 2, 9),
    Assign("STAT 3515 EP4 - Incomplete Block Design (Latin Squares)", 2, 9),
    Assign("STAT 3515 EP5 - Incomplete Block Design (Greco Latin Squares)", 2, 9),
    Assign("STAT 3515 EP5 - Two-Way factorial Completely randomized Fixed WEffects", 2, 8),
    Assign("STAT 3515 EP7 - Three-Way Factorial Completely ranomized Fixed Effects", 2, 8),
    Assign("STAT 3515 Homework", 3, 22), 
    Assign("STAT 3675 Homework", 3, 23), 
    Assign("Fill out Honors Plan + Submit", 1, 144), 
    Assign("Put together Poster Presentation for Fall Frontiers", 5, 38),
    Assign("Print Poster Presentation for Fall Frontiers", 2, 45), 
    Assign("Apply for NVIDIA Internships of Interest", 3, 2),
    Assign("Register for Data Science Day Poster Session", 0.5, 13)

]
random.shuffle(Assignments)

time = 0
sorted_data = sorted(Assignments, key=lambda item: item.deadline)
for i in range(len(sorted_data)):
    print(i, sorted_data[i])
    print(f"\t at time {time}")
    print(f"Lateness: {0 if sorted_data[i].deadline > time else sorted_data[i].deadline - (time+sorted_data[i].duration)}")
    print(60*"-")
    time += sorted_data[i].duration
# Out:
# 0 STAT 3515 Weakness Identification -> dur: 2 -> deadline: -15
# 	 at time 0
# Lateness: -17
# 1 Apply for NVIDIA Internships of Interest -> dur: 3 -> deadline: 2
# 	 at time 2
# Lateness: -3
# 2 STAT 3515 EP7 - Three-Way Factorial Completely ranomized Fixed Effects -> dur: 2 -> deadline: 8
# 	 at time 5
# Lateness: 0
# 3 STAT 3515 EP5 - Two-Way factorial Completely randomized Fixed WEffects -> dur: 2 -> deadline: 8
# 	 at time 7
# Lateness: 0
# 4 STAT 3515 EP1 - One-Way Fixed Effects -> dur: 2 -> deadline: 9
# 	 at time 9
# Lateness: -2
# 5 STAT 3515 EP3 - Randomized Complete Block Design -> dur: 2 -> deadline: 9
# 	 at time 11
# Lateness: -4
# 6 STAT 3515 EP5 - Incomplete Block Design (Greco Latin Squares) -> dur: 2 -> deadline: 9
# 	 at time 13
# Lateness: -6
# 7 STAT 3515 EP4 - Incomplete Block Design (Latin Squares) -> dur: 2 -> deadline: 9
# 	 at time 15
# Lateness: -8
# 8 STAT 3515 EP2 - One Way Random Effects -> dur: 2 -> deadline: 9
# 	 at time 17
# Lateness: -10
# 9 Register for Data Science Day Poster Session -> dur: 0.5 -> deadline: 13
# 	 at time 19
# Lateness: -6.5
# 10 STAT 3515 Homework -> dur: 3 -> deadline: 22
# 	 at time 19.5
# Lateness: 0
# 11 STAT 3675 Homework -> dur: 3 -> deadline: 23
# 	 at time 22.5
# Lateness: 0
# 12 Delphi Model Throughput -> dur: 3 -> deadline: 24
# 	 at time 25.5
# Lateness: -4.5
# 13 Delphi Model Validation -> dur: 3 -> deadline: 24
# 	 at time 28.5
# Lateness: -7.5
# 14 Delphi Model Latency -> dur: 3 -> deadline: 24
# 	 at time 31.5
# Lateness: -10.5
# 15 Put together Poster Presentation for Fall Frontiers -> dur: 5 -> deadline: 38
# 	 at time 34.5
# Lateness: 0
# 16 Data Challenge Outline - timeline work -> dur: 2 -> deadline: 43
# 	 at time 39.5
# Lateness: 0
# 17 CSE 3500 PS3 - p5 -> dur: 1 -> deadline: 45
# 	 at time 41.5
# Lateness: 0
# 18 CSE 3500 PS3 - p1 -> dur: 1 -> deadline: 45
# 	 at time 42.5
# Lateness: 0
# 19 Print Poster Presentation for Fall Frontiers -> dur: 2 -> deadline: 45
# 	 at time 43.5
# Lateness: 0
# 20 CSE 3500 PS3 - p3 -> dur: 1 -> deadline: 45
# 	 at time 45.5
# Lateness: -1.5
# 21 CSE 3500 PS3 - p2 -> dur: 1 -> deadline: 45
# 	 at time 46.5
# Lateness: -2.5
# 22 Fill out Honors Plan + Submit -> dur: 1 -> deadline: 144
# 	 at time 47.5
# Lateness: 0

# %%
# /// Sunday: 1-8 (-1) -> 1-7 (7)
# /// Monday: 8-15 (7)
# /// Tuesday: 16-22 (4)
# /// Wednesday: 23-28 (6)
# /// Thursday: 29-32 (4)
# /// Friday: 33-39 (7)
# /// Saturday: 40-47 (8)
# total: 43
# Out:
# 128
